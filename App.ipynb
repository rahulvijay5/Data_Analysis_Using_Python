# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter(action='ignore')

# Import data

Trivandrum = pd.read_csv("1trivandrum.csv");
Kollam = pd.read_csv("2kollam.csv");
Pathanamthita = pd.read_csv("3pathanamthita.csv");
Alappuzha = pd.read_csv("4alappuzha.csv");
Kottayam = pd.read_csv("5kottayam.csv");
Idukki = pd.read_csv("6idukki.csv");
Ernakulam = pd.read_csv("7ernakulam.csv");
Thrissur = pd.read_csv("8thrissur.csv");
Palakkad = pd.read_csv("9palakkad.csv");
Malappuram = pd.read_csv("10malappuram.csv");
Kozhikode = pd.read_csv("11kozhikode.csv");
Wayanad = pd.read_csv("12wayanad.csv");
Kannur = pd.read_csv("13kannur.csv");
Kasaragode = pd.read_csv("14kasaragode.csv");
Population = pd.read_csv("population.csv")

Trivandrum=Trivandrum[['District','Disability Category']]
Kollam=Kollam[['District','Disability Category']]
Pathanamthita=Pathanamthita[['District','Disability Category']]
Alappuzha=Alappuzha[['District','Disability Category']]
Kottayam=Kottayam[['District','Disability Category']]
Idukki=Idukki[['District','Disability Category']]
Ernakulam=Ernakulam[['District','Disability Category']]
Thrissur=Thrissur[['District','Disability Category']]
Palakkad=Palakkad[['District','Disability Category']]
Malappuram=Malappuram[['District','Disability Category']]
Kozhikode=Kozhikode[['District','Disability Category']]
Wayanad=Wayanad[['District','Disability Category']]
Kannur=Kannur[['District','Disability Category']]
Kasaragode=Kasaragode[['District','Disability Category']]

merged_all = pd.concat([Trivandrum,Kollam,Pathanamthita,Alappuzha,Kottayam,Idukki,Ernakulam,Thrissur,Palakkad,Malappuram,Kozhikode,Wayanad,Kannur,Kasaragode])
merged_all.to_csv('mergedfile.csv' , index=False)
merged = pd.read_csv("mergedfile.csv")
merged.describe

merged.head

u1=pd.unique(Trivandrum['Disability Category'])
u1=np.sort(u1)
# u1
u2=pd.unique(Kollam['Disability Category'])
u2=np.sort(u2)
# u2
u3=pd.unique(Pathanamthita['Disability Category'])
u3=np.sort(u3)
# u3
u4=pd.unique(Alappuzha['Disability Category'])
u4=np.sort(u4)
# u4
u5=pd.unique(Kottayam['Disability Category'])
u5=np.sort(u5)
# u5
u6=pd.unique(Idukki['Disability Category'])
u6=np.sort(u6)
# u6
u7=pd.unique(Ernakulam['Disability Category'])
# u7
u8=pd.unique(Thrissur['Disability Category'])
# u8
u9=pd.unique(Palakkad['Disability Category'])
u9=np.sort(u9)
# u9
u10=pd.unique(Malappuram['Disability Category'])
# u10
u11=pd.unique(Kozhikode['Disability Category'])
# u11
u12=pd.unique(Wayanad['Disability Category'])
u12=np.sort(u12)
# u12
u13=pd.unique(Kannur['Disability Category'])
# u13
u14=pd.unique(Kasaragode['Disability Category'])
u14=np.sort(u14)
# u14
merged['Disability Category'] = merged['Disability Category'].astype(str)
u15=pd.unique(merged['Disability Category'])
u15=np.sort(u15)
# u15

# Trivandrum['Disability Category'].value_counts()

trivandrumData = {}
kollamData = {}
pathanamthitaData = {}
alappuzhaData = {}
kottayamData = {}
idukkiData = {}
ernakulamData = {}
thrissurData = {}
palakkadData = {}
malappuramData = {}
kozhikodeData = {}
wayanadData = {}
kannurData = {}
kasaragodeData = {}
for name, group in Trivandrum.groupby('Disability Category'):
    trivandrumData[name]=group.size//2

for name, group in Kollam.groupby('Disability Category'):
    kollamData[name]=group.size//2

for name, group in Pathanamthita.groupby('Disability Category'):
    pathanamthitaData[name]=group.size//2

for name, group in Alappuzha.groupby('Disability Category'):
    alappuzhaData[name]=group.size//2

for name, group in Kottayam.groupby('Disability Category'):
    kottayamData[name]=group.size//2

for name, group in Idukki.groupby('Disability Category'):
    idukkiData[name]=group.size//2

for name, group in Ernakulam.groupby('Disability Category'):
    ernakulamData[name]=group.size//2

for name, group in Thrissur.groupby('Disability Category'):
    thrissurData[name]=group.size//2

for name, group in Palakkad.groupby('Disability Category'):
    palakkadData[name]=group.size//2

for name, group in Malappuram.groupby('Disability Category'):
    malappuramData[name]=group.size//2

for name, group in Kozhikode.groupby('Disability Category'):
    kozhikodeData[name]=group.size//2

for name, group in Wayanad.groupby('Disability Category'):
    wayanadData[name]=group.size//2

for name, group in Kannur.groupby('Disability Category'):
    kannurData[name]=group.size//2

for name, group in Kasaragode.groupby('Disability Category'):
    kasaragodeData[name]=group.size//2

data = {}
data["Trivandrum"] = trivandrumData
data["Kollam"] = kollamData
data["Pathanamthita"] = pathanamthitaData
data["Alappuzha"] = alappuzhaData
data["Kottayam"] = kottayamData
data["Idukki"] = idukkiData
data["Ernakulam"] = ernakulamData
data["Thrissur"] = thrissurData
data["Palakkad"] = palakkadData
data["Malappuram"] = malappuramData
data["Kozhikode"] = kozhikodeData
data["Wayanad"] = wayanadData
data["Kannur"] = kannurData
data["Kasaragode"] = kasaragodeData
# print(data["Kollam"]["Intellectual Disability"])

dataCsv = pd.DataFrame.from_dict(data)
dataCsv.to_csv('data.csv', index=True,header=True)
# population.to_csv('population.csv',index=True,header=True)
# Population[['Kasaragode']]

# mean = dataCsv[['Trivandrum','Kollam','Pathanamthita','Alappuzha','Kottayam','Idukki','Ernakulam','Thrissur','Palakkad','Malappuram','Kozhikode','Wayanad','Kannur','Kasaragode']].mean()
# std =dataCsv[['Trivandrum','Kollam','Pathanamthita','Alappuzha','Kottayam','Idukki','Ernakulam','Thrissur','Palakkad','Malappuram','Kozhikode','Wayanad','Kannur','Kasaragode']].std()
# dataCsv=dataCsv.assign(z_value_kasargod= (dataCsv[['Kasaragode']]-mean)/std)
# mean = dataCsv[['Trivandrum','Kollam','Pathanamthita','Alappuzha','Kottayam','Idukki','Ernakulam','Thrissur','Palakkad','Malappuram','Kozhikode','Wayanad','Kannur','Kasaragode']].mean()
# std =dataCsv[['Trivandrum','Kollam','Pathanamthita','Alappuzha','Kottayam','Idukki','Ernakulam','Thrissur','Palakkad','Malappuram','Kozhikode','Wayanad','Kannur','Kasaragode']].std()

# data = pd.read_csv("data.csv")

newdataCsv = pd.DataFrame(columns=dataCsv.columns)

newdataCsv[['Trivandrum']] = ((dataCsv[['Trivandrum']]*10000)/3301427)
newdataCsv[['Kollam']] = ((dataCsv[['Kollam']]*10000)/2635375)
newdataCsv[['Pathanamthita']] = ((dataCsv[['Pathanamthita']]*10000)/1197412)
newdataCsv[['Alappuzha']] = ((dataCsv[['Alappuzha']]*10000)/2127789)
newdataCsv[['Kottayam']] = ((dataCsv[['Kottayam']]*10000)/1974551)
newdataCsv[['Idukki']] = ((dataCsv[['Idukki']]*10000)/1108974)
newdataCsv[['Ernakulam']] = ((dataCsv[['Ernakulam']]*10000)/3282388)
newdataCsv[['Thrissur']] = ((dataCsv[['Thrissur']]*10000)/3121200)
newdataCsv[['Palakkad']] = ((dataCsv[['Palakkad']]*10000)/2809934)
newdataCsv[['Malappuram']] = ((dataCsv[['Malappuram']]*10000)/4112920)
newdataCsv[['Kozhikode']] = ((dataCsv[['Kozhikode']]*10000)/3086293)
newdataCsv[['Wayanad']] = ((dataCsv[['Wayanad']]*10000)/817420)
newdataCsv[['Kannur']] = ((dataCsv[['Kannur']]*10000)/2523003)
newdataCsv[['Kasaragode']] = ((dataCsv[['Kasaragode']]*10000)/1307375)

newdataCsv=newdataCsv.assign(mean_or_Kerela=newdataCsv[['Trivandrum','Kollam','Pathanamthita','Alappuzha','Kottayam','Idukki','Ernakulam','Thrissur','Palakkad','Malappuram','Kozhikode','Wayanad','Kannur','Kasaragode']].mean(axis=1) )
newdataCsv=newdataCsv.assign(std_dev=newdataCsv[['Trivandrum','Kollam','Pathanamthita','Alappuzha','Kottayam','Idukki','Ernakulam','Thrissur','Palakkad','Malappuram','Kozhikode','Wayanad','Kannur','Kasaragode']].std(axis=1))
newdataCsv.to_csv("newdataCsv.csv",index=True)

df = pd.read_csv('newdataCsv.csv')

df['z_value_Kasaragode'] = (df['Kasaragode']-df['mean_or_Kerela'])/df['std_dev']
df.to_csv("zvalue.csv",index=True)

sum_values = df.sum(axis=0)
sum_df = pd.DataFrame(sum_values).T

sum_df = sum_df.rename(index={0:'Total'})
# sum_df = sum_df.rename(index={1:''})

sum_df.columns = [col for col in sum_df.columns]

# Concatenate column sums dataframe to original dataframe
merged_df = pd.concat([df, sum_df])
merged_df.columns.values[0] = 'Diseases'
merged_df.loc["Total", 'Diseases'] = "Total"
merged_df.loc[7, 'Diseases'] = "Hearing Impaired"
merged_df.loc[13, 'Diseases'] = "Low Vision"
merged_df.loc[20, 'Diseases'] = "Speech and Language Disability"

merged_df
merged_df.to_csv("merged.csv", index=False)
# Out:
# Running cells with 'c:\Python311\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python311/python.exe -m pip install ipykernel -U --user --force-reinstall'
